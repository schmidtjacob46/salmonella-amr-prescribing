# %%
# !pip -q install duckdb pandas requests pyarrow

# %%
import requests
import pandas as pd

def url_ok(url: str) -> bool:
    try:
        r = requests.get(url, stream=True, timeout=20, allow_redirects=True)
        return r.status_code == 200
    except requests.RequestException:
        return False

# Known-good (from CDC archive pages) for 2020 + 2021
# The archive report pages reference these CSVs. :contentReference[oaicite:3]{index=3}
candidate_urls = {
    # Archive pattern (works for 2019–2021)
    2019: "https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2019_html_files/2019-OAP-Map-States.csv",
    2020: "https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2020_html_files/2020-OAP-Map-States.csv",
    2021: "https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2021_html_files/2021-OAP-Map-States.csv",

    # 2022 uses new direct CDC CSV format
    2022: "https://www.cdc.gov/antibiotic-use/media/csv/2022-Outpatient-Rx-Map-Data.csv",
}


available = {y: u for y, u in candidate_urls.items() if url_ok(u)}
missing = {y: u for y, u in candidate_urls.items() if y not in available}

available, missing
# Out:
# ({2020: 'https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2020_html_files/2020-OAP-Map-States.csv',
#   2021: 'https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2021_html_files/2021-OAP-Map-States.csv',
#   2022: 'https://www.cdc.gov/antibiotic-use/media/csv/2022-Outpatient-Rx-Map-Data.csv'},
#  {2019: 'https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2019_html_files/2019-OAP-Map-States.csv'})

# %%
dfs = []
for year, url in available.items():
    d = pd.read_csv(url)
    d["year"] = year
    d["source_url"] = url
    dfs.append(d)

raw = pd.concat(dfs, ignore_index=True)

raw.shape, raw.head()
# Out:
# ((157, 8),
#             State   Rate Legend Category  year  \
#  0  West Virginia  974.0         700-974  2020
#  1    Mississippi  956.0         700-974  2020
#  2        Alabama  922.0         700-974  2020
#  3      Louisiana  920.0         700-974  2020
#  4       Kentucky  887.0         700-974  2020
#
#                                            source_url  ID State  Year  \
#  0  https://archive.cdc.gov/www_cdc_gov/antibiotic...       NaN   NaN
#  1  https://archive.cdc.gov/www_cdc_gov/antibiotic...       NaN   NaN
#  2  https://archive.cdc.gov/www_cdc_gov/antibiotic...       NaN   NaN
#  3  https://archive.cdc.gov/www_cdc_gov/antibiotic...       NaN   NaN
#  4  https://archive.cdc.gov/www_cdc_gov/antibiotic...       NaN   NaN
#
#     Prescriptions per 1,000 Population
#  0                                 NaN
#  1                                 NaN
#  2                                 NaN
#  3                                 NaN
#  4                                 NaN  )

# %%
raw.columns.tolist()
# Out:
# ['State',
#  'Rate',
#  'Legend Category',
#  'year',
#  'source_url',
#  'ID State',
#  'Year',
#  'Prescriptions per 1,000 Population']

# %%
import numpy as np

clean = raw.copy()

# Standardize column names
clean.columns = [c.strip() for c in clean.columns]

# Create a unified rate column
clean["rx_per_1000"] = np.where(
    clean["Rate"].notna(),
    clean["Rate"],
    clean["Prescriptions per 1,000 Population"]
)

# Convert to numeric
clean["rx_per_1000"] = pd.to_numeric(clean["rx_per_1000"], errors="coerce")

# Standardize state + year
clean["state"] = clean["State"]
clean["year"] = clean["year"].fillna(clean["Year"])

# Keep only what we need
clean = clean[["state", "year", "rx_per_1000"]].dropna()

clean.head(), clean.shape
# Out:
# (           state  year  rx_per_1000
#  0  West Virginia  2020        974.0
#  1    Mississippi  2020        956.0
#  2        Alabama  2020        922.0
#  3      Louisiana  2020        920.0
#  4       Kentucky  2020        887.0,
#  (153, 3))

# %%
import duckdb

con = duckdb.connect()
con.register("rx_clean", clean)

# %%
con.execute("""
    SELECT year, COUNT(*) AS n_states
    FROM rx_clean
    GROUP BY year
    ORDER BY year
""").df()
# Out:
#    year  n_states
# 0  2020        51
# 1  2021        51
# 2  2022        51

# %%
import pandas as pd
import numpy as np
import re

def extract_state_rates_from_cdc_report(year: int) -> pd.DataFrame:
    """
    Extracts state-level 'antibiotic prescriptions per 1000 persons' rates
    from CDC archive report pages for years where the state list is embedded in HTML.
    Works for 2015-2018 pages like:
      https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-2016.html
    """
    url = f"https://archive.cdc.gov/www_cdc_gov/antibiotic-use/data/report-{year}.html"
    
    # read_html parses tables from the page; some years are not clean tables, so we'll fallback to text parsing
    try:
        tables = pd.read_html(url)
    except ValueError:
        tables = []

    # 1) Try to find a real table that contains State + Rate
    for t in tables:
        cols = [str(c).lower() for c in t.columns]
        if any("state" in c for c in cols) and any("rate" in c for c in cols):
            out = t.copy()
            # normalize column names
            out.columns = [str(c).strip() for c in out.columns]
            # pick likely columns
            state_col = [c for c in out.columns if "state" in c.lower()][0]
            rate_col  = [c for c in out.columns if "rate" in c.lower()][0]
            out = out[[state_col, rate_col]].rename(columns={state_col:"state", rate_col:"rx_per_1000"})
            out["year"] = year
            out["rx_per_1000"] = pd.to_numeric(out["rx_per_1000"], errors="coerce")
            out = out.dropna(subset=["state","rx_per_1000"])
            return out

    # 2) Fallback: parse the inline "State ... Rate" list from page text (works for 2015/2016/2017/2018)
    import requests
    html = requests.get(url, timeout=30).text

    # The state list appears as lines like "Alabama 1,149"
    # We'll capture state names (incl. District of Columbia) + numeric rate
    # This is conservative and will later be filtered to 51 states/DC.
    pattern = re.compile(r"\b([A-Z][A-Za-z]+(?:\s+[A-Z][A-Za-z]+)*)\s+([0-9]{1,3}(?:,[0-9]{3})*|[0-9]+)\b")
    matches = pattern.findall(re.sub(r"<[^>]+>", " ", html))  # strip tags crudely

    # Build candidate dataframe
    cand = pd.DataFrame(matches, columns=["state","rx_per_1000_raw"])
    cand["rx_per_1000"] = (
        cand["rx_per_1000_raw"].str.replace(",","", regex=False)
    )
    cand["rx_per_1000"] = pd.to_numeric(cand["rx_per_1000"], errors="coerce")
    cand["year"] = year

    # Keep only plausible US states/DC by intersecting with the states we already have (from your 2020-2022 CSVs)
    # We'll return raw candidates first; filtering happens in the merge step.
    cand = cand.dropna(subset=["rx_per_1000"])
    return cand[["state","year","rx_per_1000"]]

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Downloading lxml-6.0.2-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -------------------------------------- - 3.9/4.0 MB 33.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 21.9 MB/s  0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
older_dfs = []

for y in [2015, 2016, 2017, 2018, 2019]:
    df_y = extract_state_rates_from_cdc_report(y)
    older_dfs.append(df_y)

older_raw = pd.concat(older_dfs, ignore_index=True)

# %%
import re

def norm_state(s):
    s = re.sub(r"\s+", " ", str(s)).strip().replace("\xa0", " ")
    s = re.sub(r"\bOf\b", "of", s)
    s = re.sub(r"\s+", " ", s).strip()
    if s.lower() in ["washington dc", "district of columbia", "district of columbia."]:
        return "District of Columbia"

    return s

clean["state"] = clean["state"].apply(norm_state)
older_raw["state"] = older_raw["state"].apply(norm_state)

# %%
state_set = set(clean["state"].unique())

older = older_raw[older_raw["state"].isin(state_set)].copy()

older.groupby("year")["state"].nunique()
# Out:
# year
# 2015    51
# 2016    51
# 2017    51
# 2018    51
# Name: state, dtype: int64

# %%
d2019 = pd.read_csv("2019_report.csv")

d2019["state"] = d2019["State"].apply(norm_state)
d2019["year"] = 2019
d2019["rx_per_1000"] = pd.to_numeric(d2019["Rate"], errors="coerce")

d2019 = d2019[["state","year","rx_per_1000"]].dropna()

print("unique states:", d2019["state"].nunique())
d2019.head()
# Out:
# unique states: 51
#            state  year  rx_per_1000
# 0  West Virginia  2019         1193
# 1       Kentucky  2019         1143
# 2    Mississippi  2019         1130
# 3      Louisiana  2019         1110
# 4        Alabama  2019         1108

# %%
panel = pd.concat(
    [
        older[["state","year","rx_per_1000"]],   # 2015–2018
        d2019,                                   # 2019
        clean[["state","year","rx_per_1000"]]     # 2020–2022
    ],
    ignore_index=True
)

panel["year"] = panel["year"].astype(int)
panel = panel.drop_duplicates()

panel.groupby("year")["state"].nunique().sort_index()
# Out:
# year
# 2015    51
# 2016    51
# 2017    51
# 2018    51
# 2019    51
# 2020    51
# 2021    51
# 2022    51
# Name: state, dtype: int64

# %%
# Census regions mapping
region_map = {
    # Northeast
    "Connecticut":"Northeast","Maine":"Northeast","Massachusetts":"Northeast",
    "New Hampshire":"Northeast","Rhode Island":"Northeast","Vermont":"Northeast",
    "New Jersey":"Northeast","New York":"Northeast","Pennsylvania":"Northeast",

    # Midwest
    "Illinois":"Midwest","Indiana":"Midwest","Michigan":"Midwest","Ohio":"Midwest",
    "Wisconsin":"Midwest","Iowa":"Midwest","Kansas":"Midwest","Minnesota":"Midwest",
    "Missouri":"Midwest","Nebraska":"Midwest","North Dakota":"Midwest",
    "South Dakota":"Midwest",

    # South
    "Delaware":"South","Florida":"South","Georgia":"South","Maryland":"South",
    "North Carolina":"South","South Carolina":"South","Virginia":"South",
    "District of Columbia":"South","West Virginia":"South",
    "Alabama":"South","Kentucky":"South","Mississippi":"South",
    "Tennessee":"South","Arkansas":"South","Louisiana":"South",
    "Oklahoma":"South","Texas":"South",

    # West
    "Arizona":"West","Colorado":"West","Idaho":"West","Montana":"West",
    "Nevada":"West","New Mexico":"West","Utah":"West","Wyoming":"West",
    "Alaska":"West","California":"West","Hawaii":"West",
    "Oregon":"West","Washington":"West"
}

panel["region"] = panel["state"].map(region_map)

panel.groupby("region")["state"].nunique()
# Out:
# region
# Midwest      12
# Northeast     9
# South        17
# West         13
# Name: state, dtype: int64

# %%
import duckdb
con = duckdb.connect()
con.register("panel", panel)

con.execute("""
    SELECT
        region,
        AVG(rx_per_1000) AS baseline_rx
    FROM panel
    WHERE year BETWEEN 2015 AND 2019
    GROUP BY region
    ORDER BY baseline_rx DESC
""").df()
# Out:
#       region  baseline_rx
# 0      South   981.988235
# 1    Midwest   854.216667
# 2  Northeast   789.977778
# 3       West   629.292308

# %%
con.execute("""
    SELECT
        region,
        year,
        AVG(rx_per_1000) AS avg_rx
    FROM panel
    GROUP BY region, year
    ORDER BY region, year
""").df()
# Out:
#        region  year       avg_rx
# 0     Midwest  2015   911.583333
# 1     Midwest  2016   892.583333
# 2     Midwest  2017   860.750000
# 3     Midwest  2018   819.583333
# 4     Midwest  2019   786.583333
# 5     Midwest  2020   622.500000
# 6     Midwest  2021   646.083333
# 7     Midwest  2022   716.750000
# 8   Northeast  2015   812.666667
# 9   Northeast  2016   805.666667
# 10  Northeast  2017   800.888889
# 11  Northeast  2018   776.444444
# 12  Northeast  2019   754.222222
# 13  Northeast  2020   591.888889
# 14  Northeast  2021   577.777778
# 15  Northeast  2022   663.222222
# 16      South  2015  1009.882353
# 17      South  2016  1012.411765
# 18      South  2017   995.058824
# 19      South  2018   965.941176
# 20      South  2019   926.647059
# 21      South  2020   748.117647
# 22      South  2021   803.647059
# 23      South  2022   879.176471
# 24       West  2015   671.769231
# 25       West  2016   645.461538
# 26       West  2017   634.230769
# 27       West  2018   608.461538
# 28       West  2019   586.538462
# 29       West  2020   469.076923
# 30       West  2021   473.384615
# 31       West  2022   536.461538

# %%
con.execute("""
WITH baseline AS (
    SELECT region, AVG(rx_per_1000) AS base
    FROM panel
    WHERE year BETWEEN 2015 AND 2019
    GROUP BY region
)
SELECT
    p.region,
    p.year,
    100.0 * (AVG(p.rx_per_1000) - b.base) / b.base AS pct_change
FROM panel p
JOIN baseline b ON p.region = b.region
GROUP BY p.region, p.year, b.base
ORDER BY p.region, p.year
""").df()
# Out:
#        region  year  pct_change
# 0     Midwest  2015    6.715704
# 1     Midwest  2016    4.491444
# 2     Midwest  2017    0.764833
# 3     Midwest  2018   -4.054397
# 4     Midwest  2019   -7.917585
# 5     Midwest  2020  -27.126217
# 6     Midwest  2021  -24.365403
# 7     Midwest  2022  -16.092717
# 8   Northeast  2015    2.872092
# 9   Northeast  2016    1.985991
# 10  Northeast  2017    1.381192
# 11  Northeast  2018   -1.713128
# 12  Northeast  2019   -4.526147
# 13  Northeast  2020  -25.075248
# 14  Northeast  2021  -26.861515
# 15  Northeast  2022  -16.045458
# 16      South  2015    2.840576
# 17      South  2016    3.098156
# 18      South  2017    1.331033
# 19      South  2018   -1.634140
# 20      South  2019   -5.635625
# 21      South  2020  -23.816028
# 22      South  2021  -18.161234
# 23      South  2022  -10.469755
# 24       West  2015    6.749951
# 25       West  2016    2.569431
# 26       West  2017    0.784764
# 27       West  2018   -3.310190
# 28       West  2019   -6.793957
# 29       West  2020  -25.459613
# 30       West  2021  -24.775083
# 31       West  2022  -14.751614

# %%
CENSUS_KEY = "185b1ca09f2990cc820a87c2493004bdf478b7fd"

url = (
    f"https://api.census.gov/data/2020/dec/pl"
    f"?get=NAME,P1_001N"
    f"&for=state:*"
    f"&key={CENSUS_KEY}"
)

r = requests.get(url)
data = r.json()

pop = pd.DataFrame(data[1:], columns=data[0])
pop.rename(columns={
    "NAME": "state",
    "P1_001N": "population",
    "state": "state_code"
}, inplace=True)

pop["population"] = pop["population"].astype(int)

pop.head()
# Out:
#            state  population state_code
# 0   Pennsylvania    13002700         42
# 1     California    39538223         06
# 2  West Virginia     1793716         54
# 3           Utah     3271616         49
# 4       New York    20201249         36

# %%
# State land area in square miles (US Census Bureau official figures)
land_area_sqmi = {
    "Alabama": 50645, "Alaska": 571951, "Arizona": 113594, "Arkansas": 52035,
    "California": 155779, "Colorado": 103642, "Connecticut": 4842, "Delaware": 1949,
    "District of Columbia": 61, "Florida": 53625, "Georgia": 57513, "Hawaii": 6423,
    "Idaho": 82643, "Illinois": 55519, "Indiana": 35826, "Iowa": 55857,
    "Kansas": 81759, "Kentucky": 39486, "Louisiana": 43204, "Maine": 30843,
    "Maryland": 9707, "Massachusetts": 7800, "Michigan": 56804, "Minnesota": 79627,
    "Mississippi": 46923, "Missouri": 68742, "Montana": 145546, "Nebraska": 76824,
    "Nevada": 109781, "New Hampshire": 8953, "New Jersey": 7354, "New Mexico": 121298,
    "New York": 47126, "North Carolina": 48618, "North Dakota": 69001, "Ohio": 40861,
    "Oklahoma": 68595, "Oregon": 95988, "Pennsylvania": 44743, "Rhode Island": 1034,
    "South Carolina": 30061, "South Dakota": 75811, "Tennessee": 41235, "Texas": 261232,
    "Utah": 82170, "Vermont": 9217, "Virginia": 39490, "Washington": 66456,
    "West Virginia": 24038, "Wisconsin": 54158, "Wyoming": 97093
}

pop["state"] = pop["state"].apply(norm_state)
pop["aland_sqmi"] = pop["state"].map(land_area_sqmi)
pop["pop_density"] = pop["population"] / pop["aland_sqmi"]

pop[["state", "population", "aland_sqmi", "pop_density"]].head()
# Out:
#            state  population  aland_sqmi  pop_density
# 0   Pennsylvania    13002700     44743.0   290.608587
# 1     California    39538223    155779.0   253.809711
# 2  West Virginia     1793716     24038.0    74.620018
# 3           Utah     3271616     82170.0    39.815212
# 4       New York    20201249     47126.0   428.664623

# %%
panel = panel.merge(pop[["state", "pop_density"]], on="state", how="left")

# %%
panel = panel.sort_values(["state","year"]).copy()

# YoY change (absolute and percent)
panel["rx_yoy"] = panel.groupby("state")["rx_per_1000"].diff(1)
panel["rx_yoy_pct"] = panel.groupby("state")["rx_per_1000"].pct_change(1) * 100

# Baseline (2015–2019) per state
baseline = (
    panel.query("2015 <= year <= 2019")
         .groupby("state", as_index=False)["rx_per_1000"]
         .mean()
         .rename(columns={"rx_per_1000":"state_baseline_2015_2019"})
)

panel = panel.merge(baseline, on="state", how="left")

# Rolling 3-year mean (within each state)
panel["rx_roll3"] = (
    panel.groupby("state")["rx_per_1000"]
         .rolling(3, min_periods=1)
         .mean()
         .reset_index(level=0, drop=True)
)

panel.head()
# Out:
#      state  year  rx_per_1000 region  pop_density  rx_yoy  rx_yoy_pct  \
# 0  Alabama  2015       1149.0  South    99.205825     NaN         NaN
# 1  Alabama  2016       1188.0  South    99.205825    39.0    3.394256
# 2  Alabama  2017       1178.0  South    99.205825   -10.0   -0.841751
# 3  Alabama  2018       1158.0  South    99.205825   -20.0   -1.697793
# 4  Alabama  2019       1108.0  South    99.205825   -50.0   -4.317789
#
#    state_baseline_2015_2019     rx_roll3
# 0                    1156.2  1149.000000
# 1                    1156.2  1168.500000
# 2                    1156.2  1171.666667
# 3                    1156.2  1174.666667
# 4                    1156.2  1148.000000

# %%
q75 = baseline["state_baseline_2015_2019"].quantile(0.75)
baseline["high_baseline"] = (baseline["state_baseline_2015_2019"] >= q75).astype(int)
baseline[["state","state_baseline_2015_2019","high_baseline"]].head()
# Out:
#         state  state_baseline_2015_2019  high_baseline
# 0     Alabama                    1156.2              1
# 1      Alaska                     487.0              0
# 2     Arizona                     723.0              0
# 3    Arkansas                    1094.2              1
# 4  California                     555.6              0

# %%
covid_2020 = panel.query("year == 2020")[["state","rx_per_1000"]].rename(columns={"rx_per_1000":"rx_2020"})
resilience = baseline.merge(covid_2020, on="state", how="left")
resilience["pct_change_2020_vs_base"] = 100*(resilience["rx_2020"] - resilience["state_baseline_2015_2019"]) / resilience["state_baseline_2015_2019"]

# define resilient as top quartile (least negative / most positive change)
q75_res = resilience["pct_change_2020_vs_base"].quantile(0.75)
resilience["resilient_2020"] = (resilience["pct_change_2020_vs_base"] >= q75_res).astype(int)

resilience[["state","pct_change_2020_vs_base","resilient_2020"]].sort_values("pct_change_2020_vs_base", ascending=False).head()
# Out:
#           state  pct_change_2020_vs_base  resilient_2020
# 9       Florida               -18.204489               1
# 0       Alabama               -20.256011               1
# 24  Mississippi               -20.479122               1
# 10      Georgia               -20.642309               1
# 18    Louisiana               -21.367521               1

# %%
# Choose your target table:
target_df = baseline.merge(panel[["state","region","pop_density"]].drop_duplicates("state"), on="state", how="left")
# If using resilience target:
# target_df = resilience.merge(panel[["state","region","pop_density"]].drop_duplicates("state"), on="state", how="left")

target_df.head()
# Out:
#         state  state_baseline_2015_2019  high_baseline region  pop_density
# 0     Alabama                    1156.2              1  South    99.205825
# 1      Alaska                     487.0              0   West     1.282262
# 2     Arizona                     723.0              0   West    62.956688
# 3    Arkansas                    1094.2              1  South    57.874969
# 4  California                     555.6              0   West   253.809711

# %%
print("=== panel shape ===")
print(panel.shape)

print("\n=== columns ===")
print(panel.columns.tolist())

print("\n=== dtypes ===")
print(panel.dtypes)

print("\n=== missing values ===")
print(panel.isnull().sum())

print("\n=== year coverage ===")
print(panel.groupby("year")["state"].nunique().rename("n_states"))

print("\n=== numeric summary ===")
print(panel[["rx_per_1000", "pop_density", "rx_yoy", "rx_yoy_pct", 
             "state_baseline_2015_2019", "rx_roll3"]].describe().round(2))

print("\n=== sample rows (first 10) ===")
panel.sort_values(["state","year"]).head(10)
# Out:
# === panel shape ===
# (408, 10)
#
# === columns ===
# ['state', 'year', 'rx_per_1000', 'region', 'pop_density', 'rx_yoy', 'rx_yoy_pct', 'state_baseline_2015_2019', 'rx_roll3', 'post_covid']
#
# === dtypes ===
# state                           str
# year                          int64
# rx_per_1000                 float64
# region                          str
# pop_density                 float64
# rx_yoy                      float64
# rx_yoy_pct                  float64
# state_baseline_2015_2019    float64
# rx_roll3                    float64
# post_covid                    int64
# dtype: object
#
# === missing values ===
# state                        0
# year                         0
# rx_per_1000                  0
# region                       0
# pop_density                  0
# rx_yoy                      51
# rx_yoy_pct                  51
# state_baseline_2015_2019     0
# rx_roll3                     0
# post_covid                   0
# dtype: int64
#
# === year coverage ===
# year
# 2015    51
# 2016    51
# 2017    51
# 2018    51
# 2019    51
# 2020    51
# 2021    51
# 2022    51
# Name: n_states, dtype: int64
#
# === numeric summary ===
#        rx_per_1000  pop_density  rx_yoy  rx_yoy_pct  state_baseline_2015_2019  \
# count       408.00       408.00  357.00      357.00                    408.00
# mean        764.82       424.13  -21.47       -2.33                    828.14
# std         199.34      1563.99   70.25        9.48                    183.52
# min         348.00         1.28 -256.00      -26.19                    487.00
# 25%         621.00        44.17  -39.00       -4.94                    697.80
# 50%         745.00       108.82  -20.00       -2.29                    832.00
# 75%         890.25       230.78   11.00        1.58                    918.00
# max        1319.00     11304.02  162.00       21.10                   1244.00
#
#        rx_roll3
# count    408.00
# mean     786.40
# std      194.99
# min      368.33
# 25%      648.67
# 50%      761.50
# 75%      901.54
# max     1319.00
#
# === sample rows (first 10) ===
#      state  year  rx_per_1000 region  pop_density  rx_yoy  rx_yoy_pct  \
# 0  Alabama  2015       1149.0  South    99.205825     NaN         NaN
# 1  Alabama  2016       1188.0  South    99.205825    39.0    3.394256
# 2  Alabama  2017       1178.0  South    99.205825   -10.0   -0.841751
# 3  Alabama  2018       1158.0  South    99.205825   -20.0   -1.697793
# 4  Alabama  2019       1108.0  South    99.205825   -50.0   -4.317789
# 5  Alabama  2020        922.0  South    99.205825  -186.0  -16.787004
# 6  Alabama  2021        985.0  South    99.205825    63.0    6.832972
# 7  Alabama  2022       1030.0  South    99.205825    45.0    4.568528
# 8   Alaska  2015        511.0   West     1.282262     NaN         NaN
# 9   Alaska  2016        511.0   West     1.282262     0.0    0.000000
#
#    state_baseline_2015_2019     rx_roll3  post_covid
# 0                    1156.2  1149.000000           0
# 1                    1156.2  1168.500000           0
# 2                    1156.2  1171.666667           0
# 3                    1156.2  1174.666667           0
# 4                    1156.2  1148.000000           0
# 5                    1156.2  1062.666667           1
# 6                    1156.2  1005.000000           1
# 7                    1156.2   979.000000           1
# 8                     487.0   511.000000           0
# 9                     487.0   511.000000           0

# %%
print("Shape:", panel.shape)
print("\nColumns:", panel.columns.tolist())
print("\nMissing values:\n", panel.isnull().sum())
print("\nYear coverage:")
print(panel.groupby("year")["state"].nunique().rename("n_states"))
print("\nNumeric summary:")
panel[["rx_per_1000","pop_density","rx_yoy_pct","state_baseline_2015_2019"]].describe().round(2)
# Out:
# Shape: (408, 10)
#
# Columns: ['state', 'year', 'rx_per_1000', 'region', 'pop_density', 'rx_yoy', 'rx_yoy_pct', 'state_baseline_2015_2019', 'rx_roll3', 'post_covid']
#
# Missing values:
#  state                        0
# year                         0
# rx_per_1000                  0
# region                       0
# pop_density                  0
# rx_yoy                      51
# rx_yoy_pct                  51
# state_baseline_2015_2019     0
# rx_roll3                     0
# post_covid                   0
# dtype: int64
#
# Year coverage:
# year
# 2015    51
# 2016    51
# 2017    51
# 2018    51
# 2019    51
# 2020    51
# 2021    51
# 2022    51
# Name: n_states, dtype: int64
#
# Numeric summary:
#        rx_per_1000  pop_density  rx_yoy_pct  state_baseline_2015_2019
# count       408.00       408.00      357.00                    408.00
# mean        764.82       424.13       -2.33                    828.14
# std         199.34      1563.99        9.48                    183.52
# min         348.00         1.28      -26.19                    487.00
# 25%         621.00        44.17       -4.94                    697.80
# 50%         745.00       108.82       -2.29                    832.00
# 75%         890.25       230.78        1.58                    918.00
# max        1319.00     11304.02       21.10                   1244.00

# %%
# Better column list now that we know what's available
COLS_NEEDED = [
    "biosample_acc", "collection_date", "geo_loc_name",
    "host", "epi_type", "HHS_region",
    "FDA_lab_id", "collected_by",   
    "isolation_source", "serovar",
    "number_drugs_resistant", "number_drugs_intermediate",
    "number_drugs_susceptible", "number_drugs_tested",
    "number_amr_genes", "number_core_amr_genes",
    "AMR_genotypes", "AMR_genotypes_core", "AST_phenotypes"
]

FTP_URL = "https://ftp.ncbi.nlm.nih.gov/pathogen/Results/Salmonella/latest_snps/Metadata/PDG000000002.3928.metadata.tsv"

print("Streaming with updated columns...")
chunks = []

chunk_iter = pd.read_csv(
    FTP_URL,
    sep="\t",
    usecols=lambda c: c in COLS_NEEDED,
    chunksize=50_000,
    low_memory=False
)

for i, chunk in enumerate(chunk_iter):
    chunk["country"] = chunk["geo_loc_name"].astype(str).str.split(":").str[0].str.strip()
    chunk["state_raw"] = chunk["geo_loc_name"].astype(str).str.split(":").str[-1].str.strip()
    chunk["year"] = pd.to_numeric(
        chunk["collection_date"].astype(str).str[:4], errors="coerce"
    )
    filtered = chunk[
        (chunk["country"] == "USA") &
        (chunk["year"] >= 2015) &
        (chunk["year"] <= 2022) &
        (chunk["epi_type"].astype(str).str.lower().isin(["clinical", "human"]))
    ]
    if len(filtered) > 0:
        chunks.append(filtered)

    if i % 10 == 0:
        print(f"  {i * 50_000:,} rows processed, {sum(len(c) for c in chunks):,} kept...")

df_sal = pd.concat(chunks, ignore_index=True)
print(f"\nFinal: {len(df_sal):,} clinical USA Salmonella isolates (2015–2022)")
# Out:
# Streaming with updated columns...
#   0 rows processed, 6,208 kept...
#   500,000 rows processed, 231,228 kept...
#
# Final: 232,736 clinical USA Salmonella isolates (2015–2022)

# %%
for col in ["FDA_lab_id", "HHS_region", "collected_by", "geo_loc_name"]:
    print(f"\n=== {col} ===")
    print(f"Non-null: {df_sal[col].notna().sum():,} / {len(df_sal):,}")
    print(df_sal[col].value_counts().head(15))
# Out:
# === FDA_lab_id ===
# Non-null: 0 / 232,736
# Series([], Name: count, dtype: int64)
#
# === HHS_region ===
# Non-null: 19,721 / 232,736
# HHS_region
# 5.0     5012
# 4.0     4132
# 3.0     2971
# 8.0     1727
# 1.0     1700
# 2.0     1157
# 9.0     1063
# 10.0     991
# 6.0      635
# 7.0      333
# Name: count, dtype: int64
#
# === collected_by ===
# Non-null: 190,089 / 232,736
# collected_by
# CDC                                           186082
# SC                                              1541
# Minnesota Department of Health                   494
# NYSDOH                                           419
# cdc                                              315
# Not Collected                                    220
# HI                                                89
# Texas Department of State Health Services         71
# Penn State Animal Diagnostic Laboratory           70
# Maryland Department of Health                     67
# FDA Contracted Laboratory                         65
# Minnesota veterinary Diagnostic Laboratory        51
# TGen North                                        44
# Arizona Department of Health                      36
# Texas A&M University                              31
# Name: count, dtype: int64
#
# === geo_loc_name ===
# Non-null: 232,736 / 232,736
# geo_loc_name
# USA                230474
# USA:MN                506
# USA:NY                425
# USA:MD                279
# USA:PA                114
# USA:OR                 86
# USA:AZ                 76
# USA:TX                 75
# USA: California        62
# USA:MI                 52
# USA:FL                 49
# USA:WI                 39
# USA:CO                 38
# USA: Texas             31
# USA:SC                 31
# Name: count, dtype: int64

# %%
# Institution to state lookup for known facilities
institution_state_map = {
    "cornell university": "New York",
    "brigham and women": "Massachusetts",
    "nphl": "Nebraska",
    "contra costa public health": "California",
    "penn state animal diagnostic laboratory": "Pennsylvania",
    "tgen north": "Arizona",
    "texas a&m university": "Texas",
    "minnesota veterinary diagnostic laboratory": "Minnesota",
    "united states food and drug administration": None,  # no state info
    "ucsf": "California",                               # UC San Francisco
    "cdc:wy": "Wyoming",                                # CDC:WY -> Wyoming
    "marcos henrique de moraes": None,                  
    "missimg": None,                                    # typo for "missing"
}

state_patterns = {
    "Minnesota": "Minnesota",
    "New York": "New York",
    "Maryland": "Maryland",
    "Texas": "Texas",
    "Arizona": "Arizona",
    "Pennsylvania": "Pennsylvania",
    "South Carolina": "South Carolina",
    "Hawaii": "Hawaii",
    "Oregon": "Oregon",
    "Michigan": "Michigan",
    "Florida": "Florida",
    "Wisconsin": "Wisconsin",
    "Colorado": "Colorado",
    "California": "California",
    "Nebraska": "Nebraska",
    "Wyoming": "Wyoming",
    "Utah": "Utah",
    "Washington": "Washington",
    "Idaho": "Idaho",
    "Montana": "Montana",
    "North Dakota": "North Dakota",
    "South Dakota": "South Dakota",
    "Kansas": "Kansas",
    "Iowa": "Iowa",
    "Missouri": "Missouri",
    "Illinois": "Illinois",
    "Indiana": "Indiana",
    "Ohio": "Ohio",
    "Tennessee": "Tennessee",
    "Georgia": "Georgia",
    "Alabama": "Alabama",
    "Mississippi": "Mississippi",
    "Louisiana": "Louisiana",
    "Arkansas": "Arkansas",
    "Oklahoma": "Oklahoma",
    "Virginia": "Virginia",
    "West Virginia": "West Virginia",
    "North Carolina": "North Carolina",
    "Delaware": "Delaware",
    "Connecticut": "Connecticut",
    "Massachusetts": "Massachusetts",
    "Rhode Island": "Rhode Island",
    "Vermont": "Vermont",
    "Maine": "Maine",
    "New Hampshire": "New Hampshire",
    "New Jersey": "New Jersey",
    "New Mexico": "New Mexico",
    "Nevada": "Nevada",
    "Alaska": "Alaska",
    "District of Columbia": "District of Columbia",
}

abbrev_map = {
    "AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California",
    "CO":"Colorado","CT":"Connecticut","DE":"Delaware","FL":"Florida","GA":"Georgia",
    "HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa",
    "KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland",
    "MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi",
    "MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire",
    "NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina",
    "ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania",
    "RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee",
    "TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington",
    "WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming","DC":"District of Columbia"
}

hhs_to_census = {
    1.0: "Northeast", 2.0: "Northeast",
    3.0: "South",     4.0: "South",    6.0: "South",
    5.0: "Midwest",   7.0: "Midwest",
    8.0: "West",      9.0: "West",     10.0: "West",
}

def extract_region(row):
    # Priority 1: HHS region (most reliable)
    if pd.notna(row["HHS_region"]):
        return hhs_to_census.get(row["HHS_region"])

    cb = str(row["collected_by"]).strip().rstrip("_")
    cb_lower = cb.lower()

    # Priority 2: known institution lookup  <-- NEW
    for institution, state in institution_state_map.items():
        if institution in cb_lower:
            if state is None:
                return None
            return region_map.get(state)

    # Priority 3: exact abbreviation match
    if cb in abbrev_map:
        return region_map.get(abbrev_map[cb])

    # Priority 4: state name substring
    for state_name in state_patterns:
        if state_name.lower() in cb_lower:
            return region_map.get(state_name)

    # Priority 5: geo_loc_name state parsing
    geo = str(row["geo_loc_name"])
    if ":" in geo:
        state_part = geo.split(":")[-1].strip()
        if state_part in region_map:
            return region_map[state_part]
        if state_part in abbrev_map:
            return region_map.get(abbrev_map[state_part])

    return None

print("Extracting regions (this may take a moment on 232k rows)...")
df_sal["region"] = df_sal.apply(extract_region, axis=1)

print("\n=== Region coverage ===")
print(df_sal["region"].value_counts())
print(f"\nMapped:   {df_sal['region'].notna().sum():,} / {len(df_sal):,}")
print(f"Unmapped: {df_sal['region'].isna().sum():,} / {len(df_sal):,}")

unmapped = df_sal[df_sal["region"].isna()]["collected_by"].value_counts().head(25)
print("\n=== Top unmapped collected_by values ===")
print(unmapped)
# Out:
# Extracting regions (this may take a moment on 232k rows)...
#
# === Region coverage ===
# region
# South        9818
# Midwest      6046
# West         4261
# Northeast    3440
# Name: count, dtype: int64
#
# Mapped:   23,565 / 232,736
# Unmapped: 209,171 / 232,736
#
# === Top unmapped collected_by values ===
# collected_by
# CDC                                                                                                                                           173037
# cdc                                                                                                                                              313
# Not Collected                                                                                                                                    220
# United States Food and Drug Administration                                                                                                        25
# missimg                                                                                                                                            4
# Marcos Henrique de Moraes                                                                                                                          1
# United States Food and Drug Administration| Center for Food Safety and Applied Nutrition| Office Of Applied Research And Safety Assessment         1
# Name: count, dtype: int64

# %%
df_sal_region = df_sal[df_sal["region"].notna()].copy()

# Core AMR = clinically acquired resistance genes (excludes native mdsA/mdsB)
df_sal_region["has_core_amr"] = (df_sal_region["number_core_amr_genes"] > 0).astype(int)
df_sal_region["has_any_amr"]  = (df_sal_region["number_amr_genes"] > 2).astype(int)

region_resistance = (
    df_sal_region.groupby(["region", "year"])
    .agg(
        n_isolates        = ("biosample_acc", "count"),
        avg_amr_genes     = ("number_amr_genes", "mean"),
        avg_core_amr_genes= ("number_core_amr_genes", "mean"),
        pct_core_amr      = ("has_core_amr", "mean"),
        pct_any_amr       = ("has_any_amr", "mean"),
    )
    .reset_index()
)

region_resistance["pct_core_amr"] = (region_resistance["pct_core_amr"] * 100).round(2)
region_resistance["pct_any_amr"]  = (region_resistance["pct_any_amr"]  * 100).round(2)
region_resistance["year"]         = region_resistance["year"].astype(int)

print("=== Resistance panel ===")
print(region_resistance.to_string(index=False))

print("\n=== Isolates per region per year ===")
print(region_resistance.pivot(
    index="year", columns="region", values="n_isolates"
).fillna(0).astype(int))
# Out:
# === Resistance panel ===
#    region  year  n_isolates  avg_amr_genes  avg_core_amr_genes  pct_core_amr  pct_any_amr
#   Midwest  2015        1027       3.243427            1.252191         26.39        26.39
#   Midwest  2016        1558       3.055199            1.101412         26.77        25.93
#   Midwest  2017        2570       3.096109            1.143969         29.03        28.52
#   Midwest  2018         702       3.095442            1.170940         33.62        32.62
#   Midwest  2019          73       3.630137            1.630137         41.10        41.10
#   Midwest  2020          33       5.424242            3.424242         57.58        57.58
#   Midwest  2021          75       4.493333            2.520000         46.67        46.67
#   Midwest  2022           8       3.375000            1.375000         25.00        25.00
# Northeast  2015         573       2.694590            0.708551         21.47        21.47
# Northeast  2016         955       2.783246            0.827225         22.83        22.09
# Northeast  2017        1467       2.979550            1.039536         29.93        28.70
# Northeast  2018         313       3.265176            1.392971         33.87        32.59
# Northeast  2019          37       6.513514            4.513514         94.59        94.59
# Northeast  2020          25       5.200000            3.600000         56.00        56.00
# Northeast  2021          51       6.039216            4.039216         72.55        72.55
# Northeast  2022          19       4.578947            2.578947         57.89        57.89
#     South  2015        1237       2.459984            0.496362         14.79        14.71
#     South  2016        2781       2.575692            0.637181         22.83        21.90
#     South  2017        3353       2.579779            0.670444         18.43        18.01
#     South  2018         806       3.129032            1.168734         31.39        30.89
#     South  2019         217       2.493088            0.539171         15.21        15.21
#     South  2020          33       2.454545            0.515152         12.12        12.12
#     South  2021          59       3.627119            1.966102         37.29        37.29
#     South  2022        1332       2.352853            0.382132         13.59        13.51
#      West  2015         525       3.059048            1.131429         28.38        28.19
#      West  2016        1245       2.945382            1.016867         25.06        24.10
#      West  2017        1804       3.042129            1.089800         25.94        25.28
#      West  2018         463       2.982721            1.058315         26.57        26.13
#      West  2019          37       3.837838            1.945946         51.35        51.35
#      West  2020          26       4.000000            2.076923         38.46        38.46
#      West  2021          49       3.897959            1.938776         44.90        44.90
#      West  2022         112       2.892857            0.946429         25.89        26.79
#
# === Isolates per region per year ===
# region  Midwest  Northeast  South  West
# year
# 2015       1027        573   1237   525
# 2016       1558        955   2781  1245
# 2017       2570       1467   3353  1804
# 2018        702        313    806   463
# 2019         73         37    217    37
# 2020         33         25     33    26
# 2021         75         51     59    49
# 2022          8         19   1332   112

# %%
# Get region-year avg prescribing rate from your existing panel
rx_region = (
    panel.groupby(["region", "year"], as_index=False)
    .agg(
        avg_rx_per_1000       = ("rx_per_1000", "mean"),
        avg_pop_density       = ("pop_density", "mean"),
        avg_baseline_rx       = ("state_baseline_2015_2019", "mean"),
    )
)

# Merge
merged = rx_region.merge(region_resistance, on=["region", "year"], how="inner")

print("=== Merged panel shape:", merged.shape, "===")
print(f"Years: {sorted(merged['year'].unique())}")
print(f"Regions: {sorted(merged['region'].unique())}")
print()
print(merged.to_string(index=False))
# Out:
# === Merged panel shape: (32, 10) ===
# Years: [np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]
# Regions: ['Midwest', 'Northeast', 'South', 'West']
#
#    region  year  avg_rx_per_1000  avg_pop_density  avg_baseline_rx  n_isolates  avg_amr_genes  avg_core_amr_genes  pct_core_amr  pct_any_amr
#   Midwest  2015       911.583333       108.162558       854.216667        1027       3.243427            1.252191         26.39        26.39
#   Midwest  2016       892.583333       108.162558       854.216667        1558       3.055199            1.101412         26.77        25.93
#   Midwest  2017       860.750000       108.162558       854.216667        2570       3.096109            1.143969         29.03        28.52
#   Midwest  2018       819.583333       108.162558       854.216667         702       3.095442            1.170940         33.62        32.62
#   Midwest  2019       786.583333       108.162558       854.216667          73       3.630137            1.630137         41.10        41.10
#   Midwest  2020       622.500000       108.162558       854.216667          33       5.424242            3.424242         57.58        57.58
#   Midwest  2021       646.083333       108.162558       854.216667          75       4.493333            2.520000         46.67        46.67
#   Midwest  2022       716.750000       108.162558       854.216667           8       3.375000            1.375000         25.00        25.00
# Northeast  2015       812.666667       550.831855       789.977778         573       2.694590            0.708551         21.47        21.47
# Northeast  2016       805.666667       550.831855       789.977778         955       2.783246            0.827225         22.83        22.09
# Northeast  2017       800.888889       550.831855       789.977778        1467       2.979550            1.039536         29.93        28.70
# Northeast  2018       776.444444       550.831855       789.977778         313       3.265176            1.392971         33.87        32.59
# Northeast  2019       754.222222       550.831855       789.977778          37       6.513514            4.513514         94.59        94.59
# Northeast  2020       591.888889       550.831855       789.977778          25       5.200000            3.600000         56.00        56.00
# Northeast  2021       577.777778       550.831855       789.977778          51       6.039216            4.039216         72.55        72.55
# Northeast  2022       663.222222       550.831855       789.977778          19       4.578947            2.578947         57.89        57.89
#     South  2015      1009.882353       852.552157       981.988235        1237       2.459984            0.496362         14.79        14.71
#     South  2016      1012.411765       852.552157       981.988235        2781       2.575692            0.637181         22.83        21.90
#     South  2017       995.058824       852.552157       981.988235        3353       2.579779            0.670444         18.43        18.01
#     South  2018       965.941176       852.552157       981.988235         806       3.129032            1.168734         31.39        30.89
#     South  2019       926.647059       852.552157       981.988235         217       2.493088            0.539171         15.21        15.21
#     South  2020       748.117647       852.552157       981.988235          33       2.454545            0.515152         12.12        12.12
#     South  2021       803.647059       852.552157       981.988235          59       3.627119            1.966102         37.29        37.29
#     South  2022       879.176471       852.552157       981.988235        1332       2.352853            0.382132         13.59        13.51
#      West  2015       671.769231        67.816510       629.292308         525       3.059048            1.131429         28.38        28.19
#      West  2016       645.461538        67.816510       629.292308        1245       2.945382            1.016867         25.06        24.10
#      West  2017       634.230769        67.816510       629.292308        1804       3.042129            1.089800         25.94        25.28
#      West  2018       608.461538        67.816510       629.292308         463       2.982721            1.058315         26.57        26.13
#      West  2019       586.538462        67.816510       629.292308          37       3.837838            1.945946         51.35        51.35
#      West  2020       469.076923        67.816510       629.292308          26       4.000000            2.076923         38.46        38.46
#      West  2021       473.384615        67.816510       629.292308          49       3.897959            1.938776         44.90        44.90
#      West  2022       536.461538        67.816510       629.292308         112       2.892857            0.946429         25.89        26.79

# %%
# Flag sparse rows - use n < 100 as threshold
merged["low_n"] = merged["n_isolates"] < 100

print("=== Sparse rows (n < 100 isolates) ===")
print(merged[merged["low_n"]][["region", "year", "n_isolates", "pct_core_amr"]].to_string(index=False))

# Two analysis subsets
merged_full    = merged.copy()                        # all 32 rows
merged_reliable = merged[~merged["low_n"]].copy()    # 20 rows, n >= 100 only

print(f"\nFull panel:     {len(merged_full)} region-year observations")
print(f"Reliable panel: {len(merged_reliable)} region-year observations")
print(f"Dropped rows:   {merged['low_n'].sum()}")
# Out:
# === Sparse rows (n < 100 isolates) ===
#    region  year  n_isolates  pct_core_amr
#   Midwest  2019          73         41.10
#   Midwest  2020          33         57.58
#   Midwest  2021          75         46.67
#   Midwest  2022           8         25.00
# Northeast  2019          37         94.59
# Northeast  2020          25         56.00
# Northeast  2021          51         72.55
# Northeast  2022          19         57.89
#     South  2020          33         12.12
#     South  2021          59         37.29
#      West  2019          37         51.35
#      West  2020          26         38.46
#      West  2021          49         44.90
#
# Full panel:     32 region-year observations
# Reliable panel: 19 region-year observations
# Dropped rows:   13

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from scipy import stats

fig, axes = plt.subplots(2, 2, figsize=(13, 10))
axes = axes.flatten()

comparisons = [
    ("avg_rx_per_1000", "pct_core_amr",
     "Avg Rx per 1,000", "% Isolates with Core AMR Genes",
     "Prescribing Rate vs. Core AMR Resistance"),
    ("avg_rx_per_1000", "pct_any_amr",
     "Avg Rx per 1,000", "% Isolates with Any AMR Genes",
     "Prescribing Rate vs. Any AMR Resistance"),
    ("avg_pop_density", "pct_core_amr",
     "Avg Population Density (per sq mi)", "% Isolates with Core AMR Genes",
     "Population Density vs. Core AMR Resistance"),
    ("avg_pop_density", "avg_amr_genes",
     "Avg Population Density (per sq mi)", "Avg AMR Gene Count",
     "Population Density vs. Avg AMR Gene Count"),
]

colors = {"Northeast": "steelblue", "South": "tomato",
          "Midwest": "seagreen", "West": "darkorange"}

for ax, (x, y, xlabel, ylabel, title) in zip(axes, comparisons):
    for region, grp in merged_reliable.groupby("region"):
        ax.scatter(grp[x], grp[y], label=region,
                   color=colors[region], alpha=0.7, s=60)

    # Overall trend line
    r, p = stats.pearsonr(merged_reliable[x], merged_reliable[y])
    m, b = np.polyfit(merged_reliable[x], merged_reliable[y], 1)
    xline = np.linspace(merged_reliable[x].min(), merged_reliable[x].max(), 100)
    ax.plot(xline, m * xline + b, color="black", linestyle="--", linewidth=1.2)

    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(f"{title}\nr = {r:.2f}, p = {p:.3f}")
    ax.legend(fontsize=8)

plt.suptitle("Antibiotic Prescribing, Population Density & Resistance\n(Regional, 2015–2022)",
             fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig("resistance_correlations.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import cross_val_score, LeaveOneGroupOut
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np

model_df = merged_reliable.dropna(subset=["pct_core_amr", "avg_rx_per_1000",
                                  "avg_pop_density", "year"]).copy()

model_df["region_enc"] = LabelEncoder().fit_transform(model_df["region"])

# Features: prescribing rate, pop density, region, year
X = model_df[["avg_rx_per_1000", "avg_pop_density", "region_enc", "year"]]
y = model_df["pct_core_amr"]
groups = model_df["region_enc"]  # for group-aware CV

# Leave-one-region-out CV - more rigorous than random kfold for regional panel data
logo = LeaveOneGroupOut()

models = {
    "Linear Regression" : Pipeline([("scaler", StandardScaler()),
                                     ("model", LinearRegression())]),
    "Ridge Regression"  : Pipeline([("scaler", StandardScaler()),
                                     ("model", Ridge(alpha=1.0))]),
    "Random Forest"     : RandomForestRegressor(n_estimators=200, random_state=42),
    "Gradient Boosting" : GradientBoostingRegressor(n_estimators=200, random_state=42),
}

print("=== Model performance (Leave-One-Region-Out CV) ===")
print(f"{'Model':<22} {'R² mean':>10} {'R² std':>10} {'RMSE mean':>12}")
print("-" * 56)

results = {}
for name, model in models.items():
    r2    = cross_val_score(model, X, y, cv=logo, groups=groups, scoring="r2")
    rmse  = np.sqrt(-cross_val_score(model, X, y, cv=logo, groups=groups,
                                      scoring="neg_mean_squared_error"))
    results[name] = {"r2_mean": r2.mean(), "r2_std": r2.std(), "rmse_mean": rmse.mean()}
    print(f"{name:<22} {r2.mean():>10.3f} {r2.std():>10.3f} {rmse.mean():>12.3f}")

# Feature importance from best tree model
rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(X, y)
feat_imp = pd.Series(rf.feature_importances_,
                     index=X.columns).sort_values(ascending=False)
print("\n=== Random Forest Feature Importances ===")
print(feat_imp.round(3))

import statsmodels.formula.api as smf

print("=== OLS Regression Summary ===")
ols = smf.ols(
    "pct_core_amr ~ avg_rx_per_1000 + avg_pop_density + C(region) + year",
    data=merged_reliable
).fit()
print(ols.summary())
# Out:
# === Model performance (Leave-One-Region-Out CV) ===
# Model                     R² mean     R² std    RMSE mean
# --------------------------------------------------------
# Linear Regression      -37164.396  63370.374      142.977
# Ridge Regression           -1.403      0.632        5.773
# Random Forest              -3.327      3.166        6.203
# Gradient Boosting          -4.547      3.324        7.489
#
# === Random Forest Feature Importances ===
# avg_pop_density    0.331
# year               0.327
# avg_rx_per_1000    0.299
# region_enc         0.043
# dtype: float64
# === OLS Regression Summary ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           pct_core_amr   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     2.391
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):             0.0955
# Time:                        08:58:37   Log-Likelihood:                -54.322
# No. Observations:                  19   AIC:                             120.6
# Df Residuals:                      13   BIC:                             126.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept              -5498.4394   4876.395     -1.128      0.280    -1.6e+04    5036.371
# C(region)[T.Northeast]   367.4078    323.247      1.137      0.276    -330.924    1065.740
# C(region)[T.South]       580.1320    516.178      1.124      0.281    -535.003    1695.267
# C(region)[T.West]         -5.9508      8.585     -0.693      0.500     -24.497      12.596
# avg_rx_per_1000            0.1288      0.116      1.112      0.286      -0.121       0.379
# avg_pop_density           -0.8133      0.712     -1.142      0.274      -2.351       0.725
# year                       2.7290      2.408      1.133      0.278      -2.473       7.931
# ==============================================================================
# Omnibus:                        7.044   Durbin-Watson:                   2.428
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                4.531
# Skew:                           1.125   Prob(JB):                        0.104
# Kurtosis:                       3.811   Cond. No.                     9.19e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.11e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Drop year from OLS since it's collinear with rx rate
# Use prescribing rate change instead of level, or just bivariate

print("=== Correlation matrix ===")
print(merged_reliable[["avg_rx_per_1000", "year", "avg_pop_density", 
                         "pct_core_amr"]].corr().round(3))

# Bivariate: prescribing rate vs resistance, by region
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

fig, ax = plt.subplots(figsize=(9, 6))
colors = {"Northeast": "steelblue", "South": "tomato",
          "Midwest": "seagreen", "West": "darkorange"}

for region, grp in merged_reliable.groupby("region"):
    sc = ax.scatter(grp["avg_rx_per_1000"], grp["pct_core_amr"],
                    label=region, color=colors[region], s=80, alpha=0.85)
    # Annotate year
    for _, row in grp.iterrows():
        ax.annotate(str(row["year"])[-2:],
                    (row["avg_rx_per_1000"], row["pct_core_amr"]),
                    textcoords="offset points", xytext=(5, 3), fontsize=7,
                    color=colors[region])

# Overall trend
r, p = stats.pearsonr(merged_reliable["avg_rx_per_1000"],
                       merged_reliable["pct_core_amr"])
m, b = np.polyfit(merged_reliable["avg_rx_per_1000"],
                   merged_reliable["pct_core_amr"], 1)
xline = np.linspace(merged_reliable["avg_rx_per_1000"].min(),
                     merged_reliable["avg_rx_per_1000"].max(), 100)
ax.plot(xline, m * xline + b, "k--", linewidth=1.2,
        label=f"Overall trend (r={r:.2f}, p={p:.3f})")

ax.set_xlabel("Avg Regional Antibiotic Prescribing Rate (Rx per 1,000)", fontsize=11)
ax.set_ylabel("% Salmonella Isolates with Core AMR Genes", fontsize=11)
ax.set_title("Antibiotic Prescribing Rate vs. Salmonella AMR Resistance\nby Census Region, 2015–2022 (n≥100 isolates)", fontsize=12)
ax.legend()
plt.tight_layout()
plt.savefig("prescribing_vs_resistance.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"\nPearson r = {r:.3f}, p = {p:.3f}")
# Out:
# === Correlation matrix ===
#                  avg_rx_per_1000   year  avg_pop_density  pct_core_amr
# avg_rx_per_1000            1.000 -0.251            0.726        -0.360
# year                      -0.251  1.000            0.111        -0.115
# avg_pop_density            0.726  0.111            1.000        -0.552
# pct_core_amr              -0.360 -0.115           -0.552         1.000
# Pearson r = -0.360, p = 0.131

# %%
fig, ax = plt.subplots(figsize=(9, 6))

for region, grp in merged_reliable.groupby("region"):
    ax.scatter(grp["avg_pop_density"], grp["pct_core_amr"],
               label=region, color=colors[region], s=80, alpha=0.85)
    for _, row in grp.iterrows():
        ax.annotate(str(row["year"])[-2:],
                    (row["avg_pop_density"], row["pct_core_amr"]),
                    textcoords="offset points", xytext=(5, 3), fontsize=7,
                    color=colors[region])

r2, p2 = stats.pearsonr(merged_reliable["avg_pop_density"],
                          merged_reliable["pct_core_amr"])
m2, b2 = np.polyfit(merged_reliable["avg_pop_density"],
                     merged_reliable["pct_core_amr"], 1)
xline2 = np.linspace(merged_reliable["avg_pop_density"].min(),
                      merged_reliable["avg_pop_density"].max(), 100)
ax.plot(xline2, m2 * xline2 + b2, "k--", linewidth=1.2,
        label=f"Overall trend (r={r2:.2f}, p={p2:.3f})")

ax.set_xlabel("Avg Population Density (persons per sq mi)", fontsize=11)
ax.set_ylabel("% Salmonella Isolates with Core AMR Genes", fontsize=11)
ax.set_title("Population Density vs. Salmonella AMR Resistance\nby Census Region, 2015–2022 (n≥100 isolates)", fontsize=12)
ax.legend()
plt.tight_layout()
plt.savefig("popdensity_vs_resistance.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"Pearson r = {r2:.3f}, p = {p2:.3f}")
# Out:
# Pearson r = -0.552, p = 0.014

# %%
print("=== Within-region correlation: year vs pct_core_amr ===")
for region, grp in merged_reliable.groupby("region"):
    r_yr, p_yr = stats.pearsonr(grp["year"], grp["pct_core_amr"])
    r_rx, p_rx = stats.pearsonr(grp["avg_rx_per_1000"], grp["pct_core_amr"])
    print(f"{region:<12}  year r={r_yr:+.2f} (p={p_yr:.3f})   rx_rate r={r_rx:+.2f} (p={p_rx:.3f})   n={len(grp)}")
# Out:
# === Within-region correlation: year vs pct_core_amr ===
# Midwest       year r=+0.93 (p=0.069)   rx_rate r=-0.98 (p=0.023)   n=4
# Northeast     year r=+0.97 (p=0.027)   rx_rate r=-0.91 (p=0.090)   n=4
# South         year r=-0.23 (p=0.658)   rx_rate r=+0.33 (p=0.518)   n=6
# West          year r=-0.36 (p=0.547)   rx_rate r=+0.40 (p=0.507)   n=5

# %%
# National baseline from all isolates (including unmapped)
national = (
    df_sal_region.groupby("year")  # use full df_sal here, not just regional
    .agg(
        n_isolates=("biosample_acc", "count"),
        pct_core_amr=("has_core_amr", "mean"),
    )
    .reset_index()
)
national["pct_core_amr"] = (national["pct_core_amr"] * 100).round(2)

# Compare to your regional panel weighted average
regional_weighted = (
    merged_reliable.groupby("year")
    .apply(lambda x: np.average(x["pct_core_amr"], weights=x["n_isolates"]))
    .reset_index(name="weighted_pct_core_amr")
)

print("=== National (all isolates) vs Regional panel weighted avg ===")
comparison = national.merge(regional_weighted, on="year", how="inner")
print(comparison.to_string(index=False))
# Out:
# === National (all isolates) vs Regional panel weighted avg ===
#   year  n_isolates  pct_core_amr  weighted_pct_core_amr
# 2015.0        3362         21.59              21.594161
# 2016.0        6539         24.19              24.193338
# 2017.0        9194         24.70              24.701540
# 2018.0        2284         31.44              31.438179
# 2019.0         364         32.14              15.210000
# 2022.0        1471         15.16              14.544017
